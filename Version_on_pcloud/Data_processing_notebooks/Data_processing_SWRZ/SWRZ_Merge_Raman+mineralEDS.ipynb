# %% [markdown]
# # Import necessary packages

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
#import mineralML as mm
import Thermobar as pt
import os

# %%
#mm.__version__

# %% [markdown]
# # Now setup folders and paths

# %%
if os.name=='posix':
    slash='/'
else:
    slash='\\'

MasterFolder=os.path.dirname(os.path.dirname(os.getcwd()))

# #Folder to save figures

# figpath=MasterFolder +slash+'Figs'
# if not os.path.exists(figpath):
#     os.mkdir(figpath)

# #Folder to save full datasets

compilation_folder=MasterFolder +slash+"Data_processing_notebooks"+slash+'Data_processing_SWRZ'+slash+'Notebook_Compiled_data'
if not os.path.exists(compilation_folder):
    os.mkdir(compilation_folder)

# %% [markdown]
# # Now lets merge the SEM dataframe with the Raman data

# %% [markdown]
# ## First import the Raman data

# %%
Raman_df=pd.read_excel(compilation_folder+slash+'KL_SWRZ_Raman_only.xlsx')
Raman_df = Raman_df.loc[:, ~Raman_df.columns.str.contains('Unnamed')]

Raman_df
# Out:
#                   filename  Density g/cm3  σ Density g/cm3  \
# 0          FG04-A1-1-start       0.609630         0.007472
# 1               FG04-A1-16       0.478732         0.004766
# 2               FG04-A1-16       0.480376         0.004752
# 3         FG04-A1-16-start       0.494153         0.004861
# 4          FG04-A1-2-start       0.464893         0.009226
# ..                     ...            ...              ...
# 163             K24_40_FIA       0.113685         0.004704
# 164             K24_40_FIB       0.127505         0.004580
# 165  KL0919-013-A-rep2-6mW       0.429251         0.005502
# 166  KL0919-013-B-rep2-6mW       0.387546         0.003067
# 167  KL0919-013-C-rep2-6mW       0.374186         0.002926
#
#      σ Density g/cm3 (from Ne+peakfit)  σ Density g/cm3 (from densimeter)  \
# 0                             0.007085                           0.002372
# 1                             0.004145                           0.002353
# 2                             0.004129                           0.002353
# 3                             0.004253                           0.002355
# 4                             0.008921                           0.002352
# ..                                 ...                                ...
# 163                           0.002748                           0.003818
# 164                           0.002494                           0.003842
# 165                           0.004975                           0.002350
# 166                           0.001973                           0.002348
# 167                           0.001746                           0.002348
#
#      Corrected_Splitting  Corrected_Splitting_σ  Corrected_Splitting_σ_Ne  \
# 0             104.165317               0.014482                  0.000993
# 1             103.888961               0.009030                  0.001050
# 2             103.892543               0.008988                  0.000580
# 3             103.922437               0.009199                  0.000984
# 4             103.858713               0.019563                  0.000988
# ..                   ...                    ...                       ...
# 163           103.037164               0.006935                  0.000824
# 164           103.072041               0.006293                  0.000826
# 165           103.779896               0.011091                  0.000771
# 166           103.686032               0.004482                  0.000772
# 167           103.655591               0.003989                  0.000774
#
#      Corrected_Splitting_σ_peak_fit  power (mW)  ...   time  preferred_values  \
# 0                          0.014477       6.031  ...  39924          0.998012
# 1                          0.008988       5.998  ...  71756          0.997901
# 2                          0.008988       5.998  ...  71756          0.997935
# 3                          0.009164       6.179  ...  40819          0.998006
# 4                          0.019577       6.068  ...  40173          0.998010
# ..                              ...         ...  ...    ...               ...
# 163                        0.006900      11.969  ...  58495          0.997934
# 164                        0.006251      11.958  ...  58751          0.997934
# 165                        0.011087       6.018  ...  51070          0.997938
# 166                        0.004424       6.022  ...  51345          0.997937
# 167                        0.003921       6.019  ...  51662          0.997937
#
#      lower_values upper_values Model_name  date_object  \
# 0        0.998002     0.998021        NaN   2024-06-05
# 1        0.997891     0.997911        NaN   2024-06-05
# 2        0.997930     0.997941        NaN   2024-06-05
# 3        0.997997     0.998015        NaN   2024-06-05
# 4        0.998001     0.998020        NaN   2024-06-05
# ..            ...          ...        ...          ...
# 163      0.997926     0.997942        NaN   2024-06-07
# 164      0.997926     0.997942        NaN   2024-06-07
# 165      0.997930     0.997945        NaN   2024-06-07
# 166      0.997930     0.997945        NaN   2024-06-07
# 167      0.997930     0.997944        NaN   2024-06-07
#
#                     filename_4merge     consistent_name  \
# 0            FG04-A1-1-start_index0     FG04_A1_1_start
# 1                 FG04-A1-16_index1          FG04_A1_16
# 2                 FG04-A1-16_index2          FG04_A1_16
# 3           FG04-A1-16-start_index3    FG04_A1_16_start
# 4            FG04-A1-2-start_index4     FG04_A1_2_start
# ..                              ...                 ...
# 163             K24_40_FIA_index163          K24_40_FIA
# 164             K24_40_FIB_index164          K24_40_FIB
# 165  KL0919-013-A-rep2-6mW_index165  919_013_A_rep2_6mW
# 166  KL0919-013-B-rep2-6mW_index166  919_013_B_rep2_6mW
# 167  KL0919-013-C-rep2-6mW_index167  919_013_C_rep2_6mW
#
#           consistent_name_4merge  SO2_mol%
# 0         FG04_A1_1_start_index0       NaN
# 1              FG04_A1_16_index1       NaN
# 2              FG04_A1_16_index2       NaN
# 3        FG04_A1_16_start_index3       NaN
# 4         FG04_A1_2_start_index4       NaN
# ..                           ...       ...
# 163          K24_40_FIA_index163       NaN
# 164          K24_40_FIB_index164       NaN
# 165  919_013_A_rep2_6mW_index165  1.273502
# 166  919_013_B_rep2_6mW_index166  0.721466
# 167  919_013_C_rep2_6mW_index167  0.576049
#
# [168 rows x 102 columns]

# %% [markdown]
# ## Import the helper file with SEM names for Raman

# %%
Helper_EDS=pd.read_excel(os.getcwd()+slash+'Helper files'+slash+'Helper_SEM_merge.xlsx')
Helper_EDS = Helper_EDS.loc[:, ~Helper_EDS.columns.str.contains('Unnamed')]

Helper_EDS.head()
# Out:
#   Type Mount          filename Name_on_SEM Notes regarding SEM matching  \
# 0  Std   NaN   FG04-A1-1-start         NaN                          NaN
# 1  Std   NaN        FG04-A1-16         NaN                          NaN
# 2  Std   NaN        FG04-A1-16         NaN                          NaN
# 3  Std   NaN  FG04-A1-16-start         NaN                          NaN
# 4  Std   NaN   FG04-A1-2-start         NaN                          NaN
#
#            filename_4merge
# 0   FG04-A1-1-start_index0
# 1        FG04-A1-16_index1
# 2        FG04-A1-16_index2
# 3  FG04-A1-16-start_index3
# 4   FG04-A1-2-start_index4

# %% [markdown]
# ## Merge the helper with the Raman frame

# %%
Raman_df_wnames = Raman_df.merge(Helper_EDS, on='filename_4merge', how='left')
Raman_df_wnames
# Out:
#                 filename_x  Density g/cm3  σ Density g/cm3  \
# 0          FG04-A1-1-start       0.609630         0.007472
# 1               FG04-A1-16       0.478732         0.004766
# 2               FG04-A1-16       0.480376         0.004752
# 3         FG04-A1-16-start       0.494153         0.004861
# 4          FG04-A1-2-start       0.464893         0.009226
# ..                     ...            ...              ...
# 163             K24_40_FIA       0.113685         0.004704
# 164             K24_40_FIB       0.127505         0.004580
# 165  KL0919-013-A-rep2-6mW       0.429251         0.005502
# 166  KL0919-013-B-rep2-6mW       0.387546         0.003067
# 167  KL0919-013-C-rep2-6mW       0.374186         0.002926
#
#      σ Density g/cm3 (from Ne+peakfit)  σ Density g/cm3 (from densimeter)  \
# 0                             0.007085                           0.002372
# 1                             0.004145                           0.002353
# 2                             0.004129                           0.002353
# 3                             0.004253                           0.002355
# 4                             0.008921                           0.002352
# ..                                 ...                                ...
# 163                           0.002748                           0.003818
# 164                           0.002494                           0.003842
# 165                           0.004975                           0.002350
# 166                           0.001973                           0.002348
# 167                           0.001746                           0.002348
#
#      Corrected_Splitting  Corrected_Splitting_σ  Corrected_Splitting_σ_Ne  \
# 0             104.165317               0.014482                  0.000993
# 1             103.888961               0.009030                  0.001050
# 2             103.892543               0.008988                  0.000580
# 3             103.922437               0.009199                  0.000984
# 4             103.858713               0.019563                  0.000988
# ..                   ...                    ...                       ...
# 163           103.037164               0.006935                  0.000824
# 164           103.072041               0.006293                  0.000826
# 165           103.779896               0.011091                  0.000771
# 166           103.686032               0.004482                  0.000772
# 167           103.655591               0.003989                  0.000774
#
#      Corrected_Splitting_σ_peak_fit  power (mW)  ...  date_object  \
# 0                          0.014477       6.031  ...   2024-06-05
# 1                          0.008988       5.998  ...   2024-06-05
# 2                          0.008988       5.998  ...   2024-06-05
# 3                          0.009164       6.179  ...   2024-06-05
# 4                          0.019577       6.068  ...   2024-06-05
# ..                              ...         ...  ...          ...
# 163                        0.006900      11.969  ...   2024-06-07
# 164                        0.006251      11.958  ...   2024-06-07
# 165                        0.011087       6.018  ...   2024-06-07
# 166                        0.004424       6.022  ...   2024-06-07
# 167                        0.003921       6.019  ...   2024-06-07
#
#                     filename_4merge     consistent_name  \
# 0            FG04-A1-1-start_index0     FG04_A1_1_start
# 1                 FG04-A1-16_index1          FG04_A1_16
# 2                 FG04-A1-16_index2          FG04_A1_16
# 3           FG04-A1-16-start_index3    FG04_A1_16_start
# 4            FG04-A1-2-start_index4     FG04_A1_2_start
# ..                              ...                 ...
# 163             K24_40_FIA_index163          K24_40_FIA
# 164             K24_40_FIB_index164          K24_40_FIB
# 165  KL0919-013-A-rep2-6mW_index165  919_013_A_rep2_6mW
# 166  KL0919-013-B-rep2-6mW_index166  919_013_B_rep2_6mW
# 167  KL0919-013-C-rep2-6mW_index167  919_013_C_rep2_6mW
#
#           consistent_name_4merge  SO2_mol%    Type  Mount  \
# 0         FG04_A1_1_start_index0       NaN     Std    NaN
# 1              FG04_A1_16_index1       NaN     Std    NaN
# 2              FG04_A1_16_index2       NaN     Std    NaN
# 3        FG04_A1_16_start_index3       NaN     Std    NaN
# 4         FG04_A1_2_start_index4       NaN     Std    NaN
# ..                           ...       ...     ...    ...
# 163          K24_40_FIA_index163       NaN  Sample    NaN
# 164          K24_40_FIB_index164       NaN  Sample    NaN
# 165  919_013_A_rep2_6mW_index165  1.273502  Sample    NaN
# 166  919_013_B_rep2_6mW_index166  0.721466  Sample    NaN
# 167  919_013_C_rep2_6mW_index167  0.576049  Sample    NaN
#
#                 filename_y          Name_on_SEM  Notes regarding SEM matching
# 0          FG04-A1-1-start                  NaN                           NaN
# 1               FG04-A1-16                  NaN                           NaN
# 2               FG04-A1-16                  NaN                           NaN
# 3         FG04-A1-16-start                  NaN                           NaN
# 4          FG04-A1-2-start                  NaN                           NaN
# ..                     ...                  ...                           ...
# 163             K24_40_FIA           K24_40_FIA                           NaN
# 164             K24_40_FIB          K24_40_core                           NaN
# 165  KL0919-013-A-rep2-6mW       KL0919_013_FIA                           NaN
# 166  KL0919-013-B-rep2-6mW       KL0919_013_FIB                           NaN
# 167  KL0919-013-C-rep2-6mW  KL0919_013_FIC_away                           NaN
#
# [168 rows x 107 columns]

# %% [markdown]
# ## Import the olivine data

# %%
OlivineEDS=pd.read_excel(compilation_folder+slash+'EDS_olivine.xlsx')
OlivineEDS =OlivineEDS.loc[:, ~OlivineEDS.columns.str.contains('Unnamed')]

OlivineEDS.head()
# Out:
#       Sample Name  Total_wt%  Total_Oxide%  Al2O3     CaO  Cr2O3     FeOt  \
# 0    SanCarlos1_1    99.5029       99.5029    NaN  0.0363    NaN   9.8525
# 1    SanCarlos1_2    99.8710       99.8710    NaN  0.1326    NaN   9.6518
# 2    SanCarlos1_3    99.0721       99.0721    NaN -0.0207    NaN   9.5304
# 3    SanCarlos1_4   100.5117      100.5117    NaN  0.0380    NaN  16.5200
# 4  Springwater1_1    99.1100       99.1100    NaN  0.0042    NaN  17.0157
#
#        MgO     MnO     NiO  ...   Line_Si   Line_Ca   Line_Mn   Line_Fe  \
# 0  48.5695  0.1194  0.3790  ...  K series  K series  K series  K series
# 1  48.5980  0.2015  0.3608  ...  K series  K series  K series  K series
# 2  48.3042  0.1860  0.3784  ...  K series  K series  K series  K series
# 3  43.7118  0.3233  0.0118  ...  K series  K series  K series  K series
# 4  43.0046  0.2564  0.0092  ...  K series  K series  K series  K series
#
#    Line_Ni  Line_Al  Line_Ti  Line_Cr        SampleID        Fo
# 0       Kα      NaN      NaN      NaN    SanCarlos1_1  0.897827
# 1       Kα      NaN      NaN      NaN    SanCarlos1_2  0.899752
# 2       Kα      NaN      NaN      NaN    SanCarlos1_3  0.900345
# 3       Kα      NaN      NaN      NaN    SanCarlos1_4  0.825070
# 4       Kα      NaN      NaN      NaN  Springwater1_1  0.818350
#
# [5 rows x 139 columns]

# %% [markdown]
# ## Merge the olivines to the FI

# %%
sorted_df_renamed = OlivineEDS.rename(columns={'Sample Name': 'Name_on_SEM'})

# Merge the dataframes on the 'Name_on_SEM' column
combined_df = Raman_df_wnames.merge(sorted_df_renamed, on='Name_on_SEM', how='left')
combined_df
# Out:
#                 filename_x  Density g/cm3  σ Density g/cm3  \
# 0          FG04-A1-1-start       0.609630         0.007472
# 1               FG04-A1-16       0.478732         0.004766
# 2               FG04-A1-16       0.480376         0.004752
# 3         FG04-A1-16-start       0.494153         0.004861
# 4          FG04-A1-2-start       0.464893         0.009226
# ..                     ...            ...              ...
# 163             K24_40_FIA       0.113685         0.004704
# 164             K24_40_FIB       0.127505         0.004580
# 165  KL0919-013-A-rep2-6mW       0.429251         0.005502
# 166  KL0919-013-B-rep2-6mW       0.387546         0.003067
# 167  KL0919-013-C-rep2-6mW       0.374186         0.002926
#
#      σ Density g/cm3 (from Ne+peakfit)  σ Density g/cm3 (from densimeter)  \
# 0                             0.007085                           0.002372
# 1                             0.004145                           0.002353
# 2                             0.004129                           0.002353
# 3                             0.004253                           0.002355
# 4                             0.008921                           0.002352
# ..                                 ...                                ...
# 163                           0.002748                           0.003818
# 164                           0.002494                           0.003842
# 165                           0.004975                           0.002350
# 166                           0.001973                           0.002348
# 167                           0.001746                           0.002348
#
#      Corrected_Splitting  Corrected_Splitting_σ  Corrected_Splitting_σ_Ne  \
# 0             104.165317               0.014482                  0.000993
# 1             103.888961               0.009030                  0.001050
# 2             103.892543               0.008988                  0.000580
# 3             103.922437               0.009199                  0.000984
# 4             103.858713               0.019563                  0.000988
# ..                   ...                    ...                       ...
# 163           103.037164               0.006935                  0.000824
# 164           103.072041               0.006293                  0.000826
# 165           103.779896               0.011091                  0.000771
# 166           103.686032               0.004482                  0.000772
# 167           103.655591               0.003989                  0.000774
#
#      Corrected_Splitting_σ_peak_fit  power (mW)  ...   Line_Si   Line_Ca  \
# 0                          0.014477       6.031  ...       NaN       NaN
# 1                          0.008988       5.998  ...       NaN       NaN
# 2                          0.008988       5.998  ...       NaN       NaN
# 3                          0.009164       6.179  ...       NaN       NaN
# 4                          0.019577       6.068  ...       NaN       NaN
# ..                              ...         ...  ...       ...       ...
# 163                        0.006900      11.969  ...  K series  K series
# 164                        0.006251      11.958  ...  K series  K series
# 165                        0.011087       6.018  ...  K series  K series
# 166                        0.004424       6.022  ...  K series  K series
# 167                        0.003921       6.019  ...  K series  K series
#
#       Line_Mn   Line_Fe Line_Ni  Line_Al  Line_Ti  Line_Cr  \
# 0         NaN       NaN     NaN      NaN      NaN      NaN
# 1         NaN       NaN     NaN      NaN      NaN      NaN
# 2         NaN       NaN     NaN      NaN      NaN      NaN
# 3         NaN       NaN     NaN      NaN      NaN      NaN
# 4         NaN       NaN     NaN      NaN      NaN      NaN
# ..        ...       ...     ...      ...      ...      ...
# 163  K series  K series      Kα      NaN      NaN      NaN
# 164  K series  K series      Kα      NaN      NaN      NaN
# 165  K series  K series      Kα      NaN      NaN      NaN
# 166  K series  K series      Kα      NaN      NaN      NaN
# 167  K series  K series      Kα      NaN      NaN      NaN
#
#                 SampleID        Fo
# 0                    NaN       NaN
# 1                    NaN       NaN
# 2                    NaN       NaN
# 3                    NaN       NaN
# 4                    NaN       NaN
# ..                   ...       ...
# 163           K24_40_FIA  0.888021
# 164          K24_40_core  0.890827
# 165       KL0919_013_FIA  0.887041
# 166       KL0919_013_FIB  0.887478
# 167  KL0919_013_FIC_away  0.889405
#
# [168 rows x 245 columns]

# %% [markdown]
# ## Export merged data

# %%
combined_df.to_excel(compilation_folder+slash+'KL_SWRZ_Raman_EDS_Merged.xlsx')

# %% [markdown]
# ## Import the Glass data (Ignore we will do this later)

# %%
K24GlassEDS=pd.read_excel(compilation_folder+slash+'GlassData2024.xlsx')
K24GlassEDS=K24GlassEDS.loc[:, ~K24GlassEDS.columns.str.contains('Unnamed')]
K24GlassEDS['Sample_short'] = ['JDFD2' if 'JDF' in sample_name else 'K24' for sample_name in K24GlassEDS['Sample Name']]
K24GlassEDS.insert(1, 'Sample_short', K24GlassEDS.pop('Sample_short'))

K24GlassEDS.head()
# Out:
#        Sample Name Sample_short  Total_wt%  Total_Oxide%    Al2O3      CaO  \
# 0          JDFD2_1        JDFD2    98.5789       98.5790  13.9269  10.7876
# 1          JDFD2_2        JDFD2    98.2026       98.2026  13.8746  10.7479
# 2          JDFD2_3        JDFD2    98.5268       98.5268  13.8297  10.8564
# 3  Mount1_glass1_1          K24    99.0818       99.0818  13.9494  10.9124
# 4  Mount1_glass1_2          K24    98.9432       98.9432  13.9718  10.8649
#
#       FeOt     K2O     MgO     MnO  ...   Line_Si    Line_P    Line_S  \
# 0  11.9916  0.2097  6.5309  0.2289  ...  K series  K series  K series
# 1  11.8569  0.1747  6.6142  0.2258  ...  K series  K series  K series
# 2  11.8792  0.2095  6.5330  0.2454  ...  K series  K series  K series
# 3  10.8721  0.5062  6.3378  0.1965  ...  K series  K series  K series
# 4  10.8212  0.5404  6.3854  0.2244  ...  K series  K series  K series
#
#      Line_K   Line_Ca   Line_Ti   Line_Mn   Line_Fe         SampleID       Mg#
# 0  K series  K series  K series  K series  K series          JDFD2_1  0.542106
# 1  K series  K series  K series  K series  K series          JDFD2_2  0.548050
# 2  K series  K series  K series  K series  K series          JDFD2_3  0.544523
# 3  K series  K series  K series  K series  K series  Mount1_glass1_1  0.558930
# 4  K series  K series  K series  K series  K series  Mount1_glass1_2  0.561929
#
# [5 rows x 166 columns]
