# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_excel(r'D:\Charlotte Devitre\EBSD\Rapid_response_day1\h5oina\test.xlsx')

# %%
plt.plot(df['GOS'].loc[df['Filename'].str.contains('919')],
         
         df['equivalentRadius (um)'].loc[df['Filename'].str.contains('919')], '.r'
         
         , label='919')
plt.plot(df['GOS'].loc[df['Filename'].str.contains('013')],
         
         df['equivalentRadius (um)'].loc[df['Filename'].str.contains('013')], '*r',ms=10
         
         , label='919_008')
plt.plot(df['GOS'].loc[df['Filename'].str.contains('008')],
         
         df['equivalentRadius (um)'].loc[df['Filename'].str.contains('008')], 'dr'
         
         , label='919_008')
plt.plot(df['GOS'].loc[df['Filename'].str.contains('65')],
         
         df['equivalentRadius (um)'].loc[df['Filename'].str.contains('65')], 'sr'
         
         , label='919_65')
plt.plot(df['GOS'].loc[df['Filename'].str.contains('70')],
         
         df['equivalentRadius (um)'].loc[df['Filename'].str.contains('70')], 'xr'
         
         , label='919_70')


plt.plot(df['GOS'].loc[df['Filename'].str.contains('K24')],
         
         df['equivalentRadius (um)'].loc[df['Filename'].str.contains('K24')], '.k',
         
         label='K24')

plt.plot(df['GOS'].loc[df['Filename'].str.contains('36')],
         
         df['equivalentRadius (um)'].loc[df['Filename'].str.contains('36')], '*k', ms=10,
         
         label='K24_36')

plt.legend()

# %%
# K24_1_3 looks awful - all broken up, synneusis etc. 
df.loc[(df['Filename'].str.contains('K24')) & (df['GOS']>0.7)]
# Out:
#                                      Filename  grainID       GOS  \
# 9     \Rapid_response_day1 Specimen 1 K24_1_3      962  0.766377
# 15  \Rapid_response_day1 Specimen 1 K24_11_16      105  1.396869
# 59  \Rapid_response_day1 Specimen 1 K24_26_36       86  0.843583
# 60  \Rapid_response_day1 Specimen 1 K24_27_35       51  1.475630
# 62  \Rapid_response_day1 Specimen 1 K24_28_34      226  1.312657
# 70  \Rapid_response_day1 Specimen 1 K24_32_38      294  1.426227
#
#     Grain Size (pixels)  Grain Size (um2)  subBoundaryLength (um)  \
# 9                 16944      1.726160e+06             3085.926661
# 15                13384      6.582227e+05              905.434952
# 59                 4258      4.278375e+05             2286.441814
# 60                12398      1.243924e+06              323.987799
# 62                24905      1.230550e+06             1639.217495
# 70                 8084      8.317566e+05             1612.826279
#
# ...

# %%
df['Filename'].unique()
# Out:
# array(['\\Rapid_response_day1 Specimen 1 919_001_41',
#        '\\Rapid_response_day1 Specimen 1 919_004_43',
#        '\\Rapid_response_day1 Specimen 1 919_007_42',
#        '\\Rapid_response_day1 Specimen 1 919_008_45',
#        '\\Rapid_response_day1 Specimen 1 919_50_39',
#        '\\Rapid_response_day1 Specimen 1 919_51_40',
#        '\\Rapid_response_day1 Specimen 1 K24_1_3',
#        '\\Rapid_response_day1 Specimen 1 K24_10_14',
#        '\\Rapid_response_day1 Specimen 1 K24_11_16',
#        '\\Rapid_response_day1 Specimen 1 K24_12_17',
#        '\\Rapid_response_day1 Specimen 1 K24_13_18',
#        '\\Rapid_response_day1 Specimen 1 K24_14_19',
#        '\\Rapid_response_day1 Specimen 1 K24_15_20',
#        '\\Rapid_response_day1 Specimen 1 K24_16_23',
#        '\\Rapid_response_day1 Specimen 1 K24_18_25',
#        '\\Rapid_response_day1 Specimen 1 K24_19_27',
#        '\\Rapid_response_day1 Specimen 1 K24_2_4',
#        '\\Rapid_response_day1 Specimen 1 K24_20_26',
# ...
